# %%
import matplotlib.pyplot as plt

# read arguments, and open corresponding output file
numSamples = 10000
step = 5
f = open(r"output-10000s-8.2to8.3rs.txt", "r")

plotSamples = numSamples // step

# prep 3 arrays
a_array = [0] * plotSamples
e_array = [0] * plotSamples
t_array = [0] * plotSamples

# read file
allLines = f.readlines()
f.close()
for i in range(3, 3 + numSamples, step):
    numbers = allLines[i].split()
    a_array[(i - 3) // step] = float(numbers[0])
    e_array[(i - 3) // step] = float(numbers[1])
    t_array[(i - 3) // step] = float(numbers[2])

fig, axs = plt.subplots(2)

fig.set_size_inches(30, 40)

axs[0].plot(t_array,a_array)
axs[0].set_xlabel('Time (yrs)')
axs[0].set_ylabel('Titan\'s semimajor axis (Saturn Radii)')

axs[1].plot(t_array,e_array)
axs[1].set_xlabel('Time (yrs)')
axs[1].set_ylabel('Titan\'s eccentricity')
# Out:
# Text(0, 0.5, "Titan's eccentricity")

# %%
plotSamplesZ = int(numSamples * 0.3)

# prep 3 arrays
a_arrayZ = [0] * plotSamplesZ
e_arrayZ = [0] * plotSamplesZ
t_arrayZ = [0] * plotSamplesZ

for i in range(3 + int(0.4 * numSamples), 3 + int(0.4 * numSamples) + plotSamplesZ):
    numbers = allLines[i].split()
    a_arrayZ[(i - 3 - int(0.4 * numSamples))] = float(numbers[0])
    e_arrayZ[(i - 3 - int(0.4 * numSamples))] = float(numbers[1])
    t_arrayZ[(i - 3 - int(0.4 * numSamples))] = float(numbers[2])

figZ, axsZ = plt.subplots(2)

figZ.set_size_inches(30, 40)

axsZ[0].plot(t_arrayZ,a_arrayZ)
axsZ[0].set_xlabel('Time (yrs)')
axsZ[0].set_ylabel('Titan\'s semimajor axis (Saturn Radii)')

axsZ[1].plot(t_arrayZ,e_arrayZ)
axsZ[1].set_xlabel('Time (yrs)')
axsZ[1].set_ylabel('Titan\'s eccentricity')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-18-8e7595802a34> in <module>
#       8 for i in range(3 + int(0.4 * numSamples), 3 + int(0.4 * numSamples) + plotSamplesZ):
#       9     numbers = allLines[i].split()
# ---> 10     a_array[(i - 3 - int(0.4 * numSamples))] = float(numbers[0])
#      11     e_array[(i - 3 - int(0.4 * numSamples))] = float(numbers[1])
#      12     t_array[(i - 3 - int(0.4 * numSamples))] = float(numbers[2])
#
# IndexError: list assignment index out of range
